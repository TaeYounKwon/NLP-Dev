# %% [markdown]
# ### Keras Functional API
#
# - Sequential API는 여러층을 공유하거나 다양한 종류의 입력과 출력을 사용하는 등의 복잡한 모델을 만드는 일에 한계가 존재
#
# - 더욱 복잡한 모델 생성이 가능한 Keras Functional API 실습

# %%
# 기존 실습에서 자주 사용된 Sequential API
from keras.models import Sequential
from keras.layers import Dense

# 단순한 층을 쌓는 것만 가능
model = Sequential()
model.add(Dense(3, input_dim =4, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 3)                 15
#
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Functional API
#
# - 각 층을 일종의 함수(function)으로 정의
#
# - 각 함수를 조합하기 위한 연산자들을 제공
#
# - 입력의 크기(shape)를 명시한 입력층(Input Layer)을 모델의 앞단에 정의해줘야함!
#
# - result = Dense(128)(input) 를 아래와 같이 적을 수 있음
#
#     - dense = Dense(128)
#     - result = dense(input)

# %%
from keras.layers import Input, Dense
from keras.models import Model

inputs = Input(shape=(10,)) # 입력의 크기 지정
hidden1 = Dense(64, activation='relu')(inputs)  # 이전층을 다음층의 함수의 입력으로 사용, 변수에 할당
hidden2 = Dense(64, activation='relu')(hidden1) # 이전층을 다음층의 함수의 입력으로 사용, 변수에 할당
output = Dense(1, activation='sigmoid')(hidden2) # 이전층을 다음층의 함수의 입력으로 사용, 변수에 할당
model = Model(inputs=inputs, outputs=output) # 입력과 출력을 정의
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 10)]              0
#
#  dense_15 (Dense)            (None, 64)                704
#
#  dense_16 (Dense)            (None, 64)                4160
#
#  dense_17 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 4,929
# Trainable params: 4,929
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Sequential과 마찬가지로 model.compile, model.fit가능
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
# model.fit(data, labels)

# %%
# 변수를 지정해서 사용 가능!
inputs = Input(shape=(10,))
x = Dense(8, activation="relu")(inputs)
x = Dense(4, activation="relu")(x)
x = Dense(1, activation="linear")(x)
model = Model(inputs, x)
model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 10)]              0
#
#  dense_18 (Dense)            (None, 8)                 88
#
#  dense_19 (Dense)            (None, 4)                 36
#
#  dense_20 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 129
# Trainable params: 129
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Functional API로 선형 회귀 구현

# %%
from keras.models import Model
from keras.layers import Input, Dense 
from keras import optimizers

# %%
X = [1, 2, 3, 4, 5, 6, 7, 8, 9] # 공부하는 시간
y = [11, 22, 33, 44, 53, 66, 77, 87, 95] # 각 공부하는 시간에 맵핑되는 성적

# %%
inputs = Input(shape=(1,))
output = Dense(1, activation='linear')(inputs)
linear_model = Model(inputs, output)
sgd = optimizers.SGD(lr=0.01)
linear_model.compile(optimizer=sgd, loss='mse', metrics=['mse'])
linear_model.fit(X, y, epochs=300)
# Out:
# Epoch 1/300
# c:\Users\Jack\miniconda3\envs\jkdev\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 1/1 [==============================] - 0s 201ms/step - loss: 2779.6680 - mse: 2779.6680
# Epoch 2/300
# 1/1 [==============================] - 0s 3ms/step - loss: 343.0230 - mse: 343.0230
# Epoch 3/300
# 1/1 [==============================] - 0s 18ms/step - loss: 43.2117 - mse: 43.2117
# Epoch 4/300
# 1/1 [==============================] - 0s 3ms/step - loss: 6.3216 - mse: 6.3216
# Epoch 5/300
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7819 - mse: 1.7819
# Epoch 6/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.2227 - mse: 1.2227
# Epoch 7/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1533 - mse: 1.1533
# Epoch 8/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1442 - mse: 1.1442
# Epoch 9/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1424 - mse: 1.1424
# Epoch 10/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1416 - mse: 1.1416
# Epoch 11/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1409 - mse: 1.1409
# Epoch 12/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1403 - mse: 1.1403
# Epoch 13/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1396 - mse: 1.1396
# Epoch 14/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1390 - mse: 1.1390
# Epoch 15/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.1383 - mse: 1.1383
# Epoch 16/300
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1377 - mse: 1.1377
# Epoch 17/300
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1370 - mse: 1.1370
# Epoch 18/300
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1364 - mse: 1.1364
# Epoch 19/300
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1358 - mse: 1.1358
# Epoch 20/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1352 - mse: 1.1352
# Epoch 21/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1345 - mse: 1.1345
# Epoch 22/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1339 - mse: 1.1339
# Epoch 23/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1333 - mse: 1.1333
# Epoch 24/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1327 - mse: 1.1327
# Epoch 25/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1321 - mse: 1.1321
# Epoch 26/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1315 - mse: 1.1315
# Epoch 27/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1309 - mse: 1.1309
# Epoch 28/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1304 - mse: 1.1304
# Epoch 29/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1298 - mse: 1.1298
# Epoch 30/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1292 - mse: 1.1292
# Epoch 31/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1286 - mse: 1.1286
# Epoch 32/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1281 - mse: 1.1281
# Epoch 33/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1275 - mse: 1.1275
# Epoch 34/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1270 - mse: 1.1270
# Epoch 35/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1264 - mse: 1.1264
# Epoch 36/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1259 - mse: 1.1259
# Epoch 37/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1253 - mse: 1.1253
# Epoch 38/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1248 - mse: 1.1248
# Epoch 39/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1243 - mse: 1.1243
# Epoch 40/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1237 - mse: 1.1237
# Epoch 41/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1232 - mse: 1.1232
# Epoch 42/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1227 - mse: 1.1227
# Epoch 43/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1222 - mse: 1.1222
# Epoch 44/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1217 - mse: 1.1217
# Epoch 45/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1212 - mse: 1.1212
# Epoch 46/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1207 - mse: 1.1207
# Epoch 47/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1202 - mse: 1.1202
# Epoch 48/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1197 - mse: 1.1197
# Epoch 49/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1192 - mse: 1.1192
# Epoch 50/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1187 - mse: 1.1187
# Epoch 51/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1182 - mse: 1.1182
# Epoch 52/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1177 - mse: 1.1177
# Epoch 53/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1172 - mse: 1.1172
# Epoch 54/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1168 - mse: 1.1168
# Epoch 55/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1163 - mse: 1.1163
# Epoch 56/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1158 - mse: 1.1158
# Epoch 57/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1154 - mse: 1.1154
# Epoch 58/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1149 - mse: 1.1149
# Epoch 59/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1145 - mse: 1.1145
# Epoch 60/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1140 - mse: 1.1140
# Epoch 61/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1136 - mse: 1.1136
# Epoch 62/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1132 - mse: 1.1132
# Epoch 63/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1127 - mse: 1.1127
# Epoch 64/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1123 - mse: 1.1123
# Epoch 65/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1119 - mse: 1.1119
# Epoch 66/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1114 - mse: 1.1114
# Epoch 67/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1110 - mse: 1.1110
# Epoch 68/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1106 - mse: 1.1106
# Epoch 69/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1102 - mse: 1.1102
# Epoch 70/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1098 - mse: 1.1098
# Epoch 71/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1093 - mse: 1.1093
# Epoch 72/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1089 - mse: 1.1089
# Epoch 73/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1085 - mse: 1.1085
# Epoch 74/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1081 - mse: 1.1081
# Epoch 75/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1077 - mse: 1.1077
# Epoch 76/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1074 - mse: 1.1074
# Epoch 77/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1070 - mse: 1.1070
# Epoch 78/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1066 - mse: 1.1066
# Epoch 79/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1062 - mse: 1.1062
# Epoch 80/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1058 - mse: 1.1058
# Epoch 81/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1054 - mse: 1.1054
# Epoch 82/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1051 - mse: 1.1051
# Epoch 83/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1047 - mse: 1.1047
# Epoch 84/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1043 - mse: 1.1043
# Epoch 85/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1040 - mse: 1.1040
# Epoch 86/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1036 - mse: 1.1036
# Epoch 87/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1032 - mse: 1.1032
# Epoch 88/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1029 - mse: 1.1029
# Epoch 89/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1025 - mse: 1.1025
# Epoch 90/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1022 - mse: 1.1022
# Epoch 91/300
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1018 - mse: 1.1018
# Epoch 92/300
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1015 - mse: 1.1015
# Epoch 93/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1011 - mse: 1.1011
# Epoch 94/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1008 - mse: 1.1008
# Epoch 95/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1005 - mse: 1.1005
# Epoch 96/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.1001 - mse: 1.1001
# Epoch 97/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0998 - mse: 1.0998
# Epoch 98/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0995 - mse: 1.0995
# Epoch 99/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0992 - mse: 1.0992
# Epoch 100/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0988 - mse: 1.0988
# Epoch 101/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0985 - mse: 1.0985
# Epoch 102/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0982 - mse: 1.0982
# Epoch 103/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0979 - mse: 1.0979
# Epoch 104/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0976 - mse: 1.0976
# Epoch 105/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0973 - mse: 1.0973
# Epoch 106/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0970 - mse: 1.0970
# Epoch 107/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0967 - mse: 1.0967
# Epoch 108/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0964 - mse: 1.0964
# Epoch 109/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0961 - mse: 1.0961
# Epoch 110/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0958 - mse: 1.0958
# Epoch 111/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0955 - mse: 1.0955
# Epoch 112/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0952 - mse: 1.0952
# Epoch 113/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0949 - mse: 1.0949
# Epoch 114/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0946 - mse: 1.0946
# Epoch 115/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0943 - mse: 1.0943
# Epoch 116/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0940 - mse: 1.0940
# Epoch 117/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0938 - mse: 1.0938
# Epoch 118/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0935 - mse: 1.0935
# Epoch 119/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0932 - mse: 1.0932
# Epoch 120/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0929 - mse: 1.0929
# Epoch 121/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0927 - mse: 1.0927
# Epoch 122/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0924 - mse: 1.0924
# Epoch 123/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0921 - mse: 1.0921
# Epoch 124/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0919 - mse: 1.0919
# Epoch 125/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0916 - mse: 1.0916
# Epoch 126/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0913 - mse: 1.0913
# Epoch 127/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0911 - mse: 1.0911
# Epoch 128/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0908 - mse: 1.0908
# Epoch 129/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0906 - mse: 1.0906
# Epoch 130/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0903 - mse: 1.0903
# Epoch 131/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0901 - mse: 1.0901
# Epoch 132/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0898 - mse: 1.0898
# Epoch 133/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0896 - mse: 1.0896
# Epoch 134/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0893 - mse: 1.0893
# Epoch 135/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0891 - mse: 1.0891
# Epoch 136/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0888 - mse: 1.0888
# Epoch 137/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0886 - mse: 1.0886
# Epoch 138/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0884 - mse: 1.0884
# Epoch 139/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0881 - mse: 1.0881
# Epoch 140/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0879 - mse: 1.0879
# Epoch 141/300
# 1/1 [==============================] - 0s 15ms/step - loss: 1.0877 - mse: 1.0877
# Epoch 142/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0875 - mse: 1.0875
# Epoch 143/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0872 - mse: 1.0872
# Epoch 144/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0870 - mse: 1.0870
# Epoch 145/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0868 - mse: 1.0868
# Epoch 146/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0866 - mse: 1.0866
# Epoch 147/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0863 - mse: 1.0863
# Epoch 148/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0861 - mse: 1.0861
# Epoch 149/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0859 - mse: 1.0859
# Epoch 150/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0857 - mse: 1.0857
# Epoch 151/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0855 - mse: 1.0855
# Epoch 152/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0853 - mse: 1.0853
# Epoch 153/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0851 - mse: 1.0851
# Epoch 154/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0849 - mse: 1.0849
# Epoch 155/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0847 - mse: 1.0847
# Epoch 156/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0845 - mse: 1.0845
# Epoch 157/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0842 - mse: 1.0842
# Epoch 158/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0840 - mse: 1.0840
# Epoch 159/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0839 - mse: 1.0839
# Epoch 160/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0837 - mse: 1.0837
# Epoch 161/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0835 - mse: 1.0835
# Epoch 162/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0833 - mse: 1.0833
# Epoch 163/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0831 - mse: 1.0831
# Epoch 164/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0829 - mse: 1.0829
# Epoch 165/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0827 - mse: 1.0827
# Epoch 166/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0825 - mse: 1.0825
# Epoch 167/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0823 - mse: 1.0823
# Epoch 168/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0821 - mse: 1.0821
# Epoch 169/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0820 - mse: 1.0820
# Epoch 170/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0818 - mse: 1.0818
# Epoch 171/300
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0816 - mse: 1.0816
# Epoch 172/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0814 - mse: 1.0814
# Epoch 173/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0812 - mse: 1.0812
# Epoch 174/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0811 - mse: 1.0811
# Epoch 175/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0809 - mse: 1.0809
# Epoch 176/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0807 - mse: 1.0807
# Epoch 177/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0805 - mse: 1.0805
# Epoch 178/300
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0804 - mse: 1.0804
# Epoch 179/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0802 - mse: 1.0802
# Epoch 180/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0800 - mse: 1.0800
# Epoch 181/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0799 - mse: 1.0799
# Epoch 182/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0797 - mse: 1.0797
# Epoch 183/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0796 - mse: 1.0796
# Epoch 184/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0794 - mse: 1.0794
# Epoch 185/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0792 - mse: 1.0792
# Epoch 186/300
# 1/1 [==============================] - 0s 15ms/step - loss: 1.0791 - mse: 1.0791
# Epoch 187/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0789 - mse: 1.0789
# Epoch 188/300
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0788 - mse: 1.0788
# Epoch 189/300
# 1/1 [==============================] - 0s 15ms/step - loss: 1.0786 - mse: 1.0786
# Epoch 190/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0785 - mse: 1.0785
# Epoch 191/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0783 - mse: 1.0783
# Epoch 192/300
# 1/1 [==============================] - 0s 15ms/step - loss: 1.0781 - mse: 1.0781
# Epoch 193/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0780 - mse: 1.0780
# Epoch 194/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0779 - mse: 1.0779
# Epoch 195/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0777 - mse: 1.0777
# Epoch 196/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0776 - mse: 1.0776
# Epoch 197/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0774 - mse: 1.0774
# Epoch 198/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0773 - mse: 1.0773
# Epoch 199/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0771 - mse: 1.0771
# Epoch 200/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0770 - mse: 1.0770
# Epoch 201/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0768 - mse: 1.0768
# Epoch 202/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0767 - mse: 1.0767
# Epoch 203/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0766 - mse: 1.0766
# Epoch 204/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0764 - mse: 1.0764
# Epoch 205/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0763 - mse: 1.0763
# Epoch 206/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0762 - mse: 1.0762
# Epoch 207/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0760 - mse: 1.0760
# Epoch 208/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0759 - mse: 1.0759
# Epoch 209/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0758 - mse: 1.0758
# Epoch 210/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0756 - mse: 1.0756
# Epoch 211/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0755 - mse: 1.0755
# Epoch 212/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0754 - mse: 1.0754
# Epoch 213/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0752 - mse: 1.0752
# Epoch 214/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0751 - mse: 1.0751
# Epoch 215/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0750 - mse: 1.0750
# Epoch 216/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0749 - mse: 1.0749
# Epoch 217/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0748 - mse: 1.0748
# Epoch 218/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0746 - mse: 1.0746
# Epoch 219/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0745 - mse: 1.0745
# Epoch 220/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0744 - mse: 1.0744
# Epoch 221/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0743 - mse: 1.0743
# Epoch 222/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0741 - mse: 1.0741
# Epoch 223/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0740 - mse: 1.0740
# Epoch 224/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0739 - mse: 1.0739
# Epoch 225/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0738 - mse: 1.0738
# Epoch 226/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0737 - mse: 1.0737
# Epoch 227/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0736 - mse: 1.0736
# Epoch 228/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0735 - mse: 1.0735
# Epoch 229/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0733 - mse: 1.0733
# Epoch 230/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0732 - mse: 1.0732
# Epoch 231/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0731 - mse: 1.0731
# Epoch 232/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0730 - mse: 1.0730
# Epoch 233/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0729 - mse: 1.0729
# Epoch 234/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0728 - mse: 1.0728
# Epoch 235/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0727 - mse: 1.0727
# Epoch 236/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0726 - mse: 1.0726
# Epoch 237/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0725 - mse: 1.0725
# Epoch 238/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0724 - mse: 1.0724
# Epoch 239/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0723 - mse: 1.0723
# Epoch 240/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0722 - mse: 1.0722
# Epoch 241/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0721 - mse: 1.0721
# Epoch 242/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0720 - mse: 1.0720
# Epoch 243/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0719 - mse: 1.0719
# Epoch 244/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0718 - mse: 1.0718
# Epoch 245/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0717 - mse: 1.0717
# Epoch 246/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0716 - mse: 1.0716
# Epoch 247/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0715 - mse: 1.0715
# Epoch 248/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0714 - mse: 1.0714
# Epoch 249/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0713 - mse: 1.0713
# Epoch 250/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0712 - mse: 1.0712
# Epoch 251/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0711 - mse: 1.0711
# Epoch 252/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0710 - mse: 1.0710
# Epoch 253/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0709 - mse: 1.0709
# Epoch 254/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0708 - mse: 1.0708
# Epoch 255/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0708 - mse: 1.0708
# Epoch 256/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0707 - mse: 1.0707
# Epoch 257/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0706 - mse: 1.0706
# Epoch 258/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0705 - mse: 1.0705
# Epoch 259/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0704 - mse: 1.0704
# Epoch 260/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0703 - mse: 1.0703
# Epoch 261/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0702 - mse: 1.0702
# Epoch 262/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0701 - mse: 1.0701
# Epoch 263/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0701 - mse: 1.0701
# Epoch 264/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0700 - mse: 1.0700
# Epoch 265/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0699 - mse: 1.0699
# Epoch 266/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0698 - mse: 1.0698
# Epoch 267/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0697 - mse: 1.0697
# Epoch 268/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0697 - mse: 1.0697
# Epoch 269/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0696 - mse: 1.0696
# Epoch 270/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0695 - mse: 1.0695
# Epoch 271/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0694 - mse: 1.0694
# Epoch 272/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0693 - mse: 1.0693
# Epoch 273/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0693 - mse: 1.0693
# Epoch 274/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0692 - mse: 1.0692
# Epoch 275/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0691 - mse: 1.0691
# Epoch 276/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0690 - mse: 1.0690
# Epoch 277/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0690 - mse: 1.0690
# Epoch 278/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0689 - mse: 1.0689
# Epoch 279/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0688 - mse: 1.0688
# Epoch 280/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0687 - mse: 1.0687
# Epoch 281/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0687 - mse: 1.0687
# Epoch 282/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0686 - mse: 1.0686
# Epoch 283/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0685 - mse: 1.0685
# Epoch 284/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0684 - mse: 1.0684
# Epoch 285/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0684 - mse: 1.0684
# Epoch 286/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0683 - mse: 1.0683
# Epoch 287/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0682 - mse: 1.0682
# Epoch 288/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0682 - mse: 1.0682
# Epoch 289/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0681 - mse: 1.0681
# Epoch 290/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0680 - mse: 1.0680
# Epoch 291/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0680 - mse: 1.0680
# Epoch 292/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0679 - mse: 1.0679
# Epoch 293/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0678 - mse: 1.0678
# Epoch 294/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0678 - mse: 1.0678
# Epoch 295/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0677 - mse: 1.0677
# Epoch 296/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0676 - mse: 1.0676
# Epoch 297/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0676 - mse: 1.0676
# Epoch 298/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0675 - mse: 1.0675
# Epoch 299/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0675 - mse: 1.0675
# Epoch 300/300
# 1/1 [==============================] - 0s 0s/step - loss: 1.0674 - mse: 1.0674

# %% [markdown]
# ### 로지스틱 회귀

# %%
from keras.layers import Input, Dense
from keras.models import Model

inputs = Input(shape=(3,))
output = Dense(1, activation='sigmoid')(inputs)
logistic_model = Model(inputs, output)

# %% [markdown]
# ### 다중 입력을 받는 모델

# %%
# 최종 완성된 다중 입력, 다중 출력 모델의 예
# model = Model(inputs=[a1, a2], outputs=[b1, b2, b3])

# %%
from keras.layers import Input, Dense, concatenate
from keras.models import Model

# 두 개의 입력층을 정의
inputA = Input(shape=(64,))
inputB = Input(shape=(128,))

# 첫번째 입력층으로부터 분기되어 진행되는 인공 신경망을 정의
x = Dense(16, activation="relu")(inputA)
x = Dense(8, activation="relu")(x)
x = Model(inputs=inputA, outputs=x)

# 두번째 입력층으로부터 분기되어 진행되는 인공 신경망을 정의
y = Dense(64, activation="relu")(inputB)
y = Dense(32, activation="relu")(y)
y = Dense(8, activation="relu")(y)
y = Model(inputs=inputB, outputs=y)

# 두개의 인공 신경망의 출력을 연결(concatenate)
result = concatenate([x.output, y.output])

z = Dense(2, activation="relu")(result)
z = Dense(1, activation="linear")(z)

model = Model(inputs=[x.input, y.input], outputs=z)

# %% [markdown]
# ### RNN 은닉층 사용

# %%
from keras.layers import Input, Dense, LSTM
from keras.models import Model

inputs = Input(shape=(50,1))
lstm_layer = LSTM(10)(inputs)
x = Dense(10, activation='relu')(lstm_layer)
output = Dense(1, activation='sigmoid')(x)

model = Model(inputs=inputs, outputs=output)

# %% [markdown]
# ### 서브 클래싱 API로 구현한 선형 회귀

# %%
import tensorflow as tf 
import keras

# %%
class LinearRegression(tf.keras.Model):
  def __init__(self):
    super(LinearRegression, self).__init__()
    self.linear_layer = keras.layers.Dense(1, input_dim=1, activation='linear')

  def call(self, x):
    y_pred = self.linear_layer(x)

    return y_pred

# %%
model = LinearRegression()
X = [1, 2, 3, 4, 5, 6, 7, 8, 9] # 공부하는 시간
y = [11, 22, 33, 44, 53, 66, 77, 87, 95] # 각 공부하는 시간에 맵핑되는 성적
sgd = keras.optimizers.SGD(lr=0.01)
model.compile(optimizer=sgd, loss='mse', metrics=['mse'])
model.fit(X, y, epochs=300)
# Out:
# Epoch 1/300
# c:\Users\Jack\miniconda3\envs\jkdev\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 6
#       4 sgd = keras.optimizers.SGD(lr=0.01)
#       5 model.compile(optimizer=sgd, loss='mse', metrics=['mse'])
# ----> 6 model.fit(X, y, epochs=300)
#
# File c:\Users\Jack\miniconda3\envs\jkdev\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_fileujkp0m3j.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# File ~\AppData\Local\Temp\__autograph_generated_filepbg_qf1q.py:10, in outer_factory.<locals>.inner_factory.<locals>.tf__call(self, x)
#       8 do_return = False
#       9 retval_ = ag__.UndefinedReturnValue()
# ---> 10 y_pred = ag__.converted_call(ag__.ld(self).linear_layer, (ag__.ld(x),), None, fscope)
#      11 try:
#      12     do_return = True
#
# ValueError: in user code:
#
#     File "c:\Users\Jack\miniconda3\envs\jkdev\lib\site-packages\keras\engine\training.py", line 1249, in train_function  *
#         return step_function(self, iterator)
#     File "c:\Users\Jack\miniconda3\envs\jkdev\lib\site-packages\keras\engine\training.py", line 1233, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\Jack\miniconda3\envs\jkdev\lib\site-packages\keras\engine\training.py", line 1222, in run_step  **
#         outputs = model.train_step(data)
#     File "c:\Users\Jack\miniconda3\envs\jkdev\lib\site-packages\keras\engine\training.py", line 1023, in train_step
#         y_pred = self(x, training=True)
#     File "c:\Users\Jack\miniconda3\envs\jkdev\lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\Jack\AppData\Local\Temp\__autograph_generated_filepbg_qf1q.py", line 10, in tf__call
#         y_pred = ag__.converted_call(ag__.ld(self).linear_layer, (ag__.ld(x),), None, fscope)
#
#     ValueError: Exception encountered when calling layer 'linear_regression_1' (type LinearRegression).
#
#     in user code:
#
#         File "C:\Users\Jack\AppData\Local\Temp\ipykernel_5712\1371838990.py", line 7, in call  *
#             y_pred = self.linear_layer(x)
#         File "c:\Users\Jack\miniconda3\envs\jkdev\lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler  **
#             raise e.with_traceback(filtered_tb) from None
#         File "c:\Users\Jack\miniconda3\envs\jkdev\lib\site-packages\keras\engine\input_spec.py", line 250, in assert_input_compatibility
#             raise ValueError(
#
#         ValueError: Input 0 of layer "dense_1" is incompatible with the layer: expected min_ndim=2, found ndim=1. Full shape received: (None,)
#
#
#     Call arguments received by layer 'linear_regression_1' (type LinearRegression):
#       • x=tf.Tensor(shape=(None,), dtype=int32)
